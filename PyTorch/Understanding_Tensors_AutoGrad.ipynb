# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1+cu124

# %%
if torch.cuda.is_available():
  print(f'GPU is available')
  print(f'Using GPU: {torch.cuda.get_device_name(0)}')
else:
  print(f'running on CPU')
# Out:
# GPU is available
# Using GPU: Tesla T4

# %% [markdown]
# # **Creating a Tensor**

# %%
a = torch.empty(2,3)
type(a)
# Out:
# torch.Tensor

# %%
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
torch.ones(2,3)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
torch.rand(2,3)
# Out:
# tensor([[0.1628, 0.8229, 0.6604],
#         [0.3758, 0.7868, 0.7735]])

# %% [markdown]
# # **Tensor Shapes**

# %%
x = torch.tensor([[1,2,3],[4,5,6]])

# %%
x.shape
# Out:
# torch.Size([2, 3])

# %% [markdown]
# # **Data Types**

# %%
torch.tensor([1.0,2.0,3.0], dtype=torch.int32)
# Out:
# tensor([1, 2, 3], dtype=torch.int32)

# %%
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x ** 2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)
